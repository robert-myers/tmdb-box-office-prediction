# %%
from scipy import stats
from itertools import chain
from collections import Counter
from datetime import datetime
from dateutil.relativedelta import relativedelta
from math import inf

import calendar
import numpy as np
import ast
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# pd.set_option("display.float_format", lambda x: "{:,.2f}".format(x))
# pd.options.mode.use_inf_as_na = True
pd.set_option("display.max_columns", None)
sns.set(style="ticks")

# plt.style.use("seaborn")
# plt.xkcd()

# %matplotlib inline

# %%
for i, (x, y) in enumerate(zip(pd.read_csv("data/train.csv").shape, pd.read_csv("data/test.csv").shape)):
    print(x) if x > y else print(y) if i else print(x + y)
# Out:
# 7398
# 23

# %%
df = pd.read_csv("data/train.csv").merge(pd.read_csv("data/test.csv"), how="outer")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7398 entries, 0 to 7397
# Data columns (total 23 columns):
# id                       7398 non-null int64
# belongs_to_collection    1481 non-null object
# budget                   7398 non-null int64
# genres                   7375 non-null object
# homepage                 2366 non-null object
# imdb_id                  7398 non-null object
# original_language        7398 non-null object
# original_title           7398 non-null object
# overview                 7376 non-null object
# popularity               7398 non-null float64
# poster_path              7396 non-null object
# production_companies     6984 non-null object
# production_countries     7241 non-null object
# release_date             7397 non-null object
# runtime                  7392 non-null float64
# spoken_languages         7336 non-null object
# status                   7396 non-null object
# tagline                  5938 non-null object
# title                    7395 non-null object
# Keywords                 6729 non-null object
# cast                     7372 non-null object
# crew                     7360 non-null object
# revenue                  3000 non-null float64
# dtypes: float64(3), int64(2), object(18)
# memory usage: 1.4+ MB

# %% [markdown]
# # READ

# %%
train_df = pd.read_csv("data/train.csv")

# %% [markdown]
# # CLEAN

# %%
dictionary_columns = ["belongs_to_collection", "genres", "production_companies", "production_countries", "spoken_languages", "Keywords", "cast", "crew"]

for column in dictionary_columns:
    train_df[column] = train_df[column].apply(lambda row: ast.literal_eval(row) if not pd.isna(row) else [])
    
train_df["release_date"] = pd.to_datetime(train_df["release_date"])
train_df["release_date"] = train_df["release_date"].apply(lambda row: row - relativedelta(years=100) if row >= datetime.now() else row)

# train_df = train_df[(train_df["budget"] > 0) & (train_df["revenue"] > 0)]
train_df = train_df[(train_df["budget"] >= 15_000) & (train_df["revenue"] >= 100_000)]

# %% [markdown]
# # CALCULATE

# %%
train_df["roi"] = train_df["revenue"] / train_df["budget"]
train_df["adjusted_roi"] = train_df["revenue"] / (train_df["budget"] * 2)

train_df["release_year"] = train_df["release_date"].map(lambda x: x.year)
train_df["release_month"] = train_df["release_date"].map(lambda x: x.month)
train_df["release_day"] = train_df["release_date"].map(lambda x: x.day)

# %% [markdown]
# # DESCRIBE

# %%
train_df.loc[:, train_df.columns != "id"].describe()
# Out:
#              budget   popularity      runtime       revenue           roi  \
# count  2.091000e+03  2091.000000  2091.000000  2.091000e+03   2091.000000
# mean   3.213771e+07     9.960269   110.519847  9.090978e+07     12.545935
# std    4.074913e+07    13.996276    22.432759  1.579297e+08    296.055279
# min    1.500000e+04     0.003013     0.000000  1.006590e+05      0.005165
# 25%    6.000000e+06     5.671845    96.000000  8.487733e+06      0.882709
# 50%    1.800000e+07     8.473369   106.000000  3.220403e+07      2.081863
# 75%    4.000000e+07    11.806200   121.000000  1.030759e+08      4.211848
# max    3.800000e+08   294.337037   338.000000  1.519558e+09  12890.386667
#
#        adjusted_roi  release_year  release_month  release_day
# count   2091.000000   2091.000000    2091.000000  2091.000000
# mean       6.272967   2000.017217       6.877571    15.111908
# std      148.027640     15.430805       3.408170     8.542206
# min        0.002582   1921.000000       1.000000     1.000000
# 25%        0.441354   1994.000000       4.000000     8.000000
# 50%        1.040932   2004.000000       7.000000    15.000000
# 75%        2.105924   2011.000000      10.000000    22.000000
# max     6445.193333   2017.000000      12.000000    31.000000

# %%
train_df.sort_values(by="budget", ascending=True).head(20)
# train_df["production_companies"][11]
train_df[["title", "budget", "revenue"]]
# Out:
#                                          title    budget    revenue
# 0                       Hot Tub Time Machine 2  14000000   12314651
# 1     The Princess Diaries 2: Royal Engagement  40000000   95149435
# 2                                     Whiplash   3300000   13092000
# 3                                      Kahaani   1200000   16000000
# 5       Pinocchio and the Emperor of the Night   8000000    3261638
# ...                                        ...       ...        ...
# 2992                       The Thief of Bagdad   1135654    1213880
# 2993                              The Terminal  60000000  219417255
# 2997                   The Long Kiss Goodnight  65000000   89456761
# 2998                          Along Came Polly  42000000  171963386
# 2999                                 Abduction  35000000   82087155
#
# [2091 rows x 3 columns]

# %%
sns.pairplot(train_df[["budget", "popularity", "release_date", "runtime", "revenue", "roi"]],
             markers="+", diag_kind="kde", kind="reg")

plt.tight_layout()

# %%
"""
# read
test_df = pd.read_csv("data/test.csv")

# clean
test_df.drop("status", axis=1, inplace=True)
# test_df = test_df[test_df["budget"] >= 15000]

# describe
test_df.describe(include="all")

# test_df.sort_values(by="budget").head(10)
""";

# %%
fig, ax = plt.subplots(figsize=(32, 8), sharex=True, sharey=True)

train_df["revenue"].hist(bins=1000, ax=ax, alpha=0.5)
train_df["budget"].hist(bins=250, ax=ax, alpha=0.5)

ax.set_xlim((0, 100_000_000))
# ax.set_ylim((0, 175))
ax.legend(["revenue", "budget"], fontsize="xx-large")

plt.tight_layout()

# %%
# train_df.head()

# %%
# lists_of_genres = train_df["genres"].apply(lambda genres: [genre["name"] for genre in genres] if genres else ["no data"])
# Counter(chain(*lists_of_genres)).most_common()

# %%
# lists_of_production_companies = train_df["production_companies"].apply(lambda production_companies: [production_company["name"] for production_company in production_companies] if production_companies else ["no data"])
# Counter(chain(*lists_of_production_companies)).most_common(21)

# %%
def count_dict_items(df, dct_columns):
    top_counts = []
    for column in dct_columns:
        top_count = Counter(chain(*df[column].apply(lambda row: [dct["name"] for dct in row] if row else ["NO DATA"]))).most_common()
        top_counts.append(top_count)
    return top_counts

top_counts = count_dict_items(train_df, dictionary_columns)

top_counts_df = pd.DataFrame(top_counts, index=dictionary_columns).T
top_counts_df.head(50)
# top_counts_df["production_companies"].dropna().head(10)
# Out:
#                               belongs_to_collection                  genres  \
# 0                                   (NO DATA, 1602)           (Drama, 1031)
# 1                       (James Bond Collection, 16)           (Comedy, 696)
# 2                   (Friday the 13th Collection, 7)         (Thriller, 604)
# 3                             (Rocky Collection, 4)           (Action, 596)
# 4                           (Ice Age Collection, 4)          (Romance, 387)
# 5          (The Fast and the Furious Collection, 4)        (Adventure, 368)
# 6                             (Rambo Collection, 4)            (Crime, 359)
# 7                             (Alien Collection, 4)  (Science Fiction, 240)
# 8                     (Resident Evil Collection, 4)           (Horror, 231)
# 9                      (Child's Play Collection, 4)           (Family, 194)
# 10                     (Transformers Collection, 4)          (Fantasy, 184)
# 11              (Paranormal Activity Collection, 4)          (Mystery, 176)
# 12                        (Rush Hour Collection, 3)        (Animation, 105)
# 13      (The Pink Panther (Original) Collection, 3)          (History, 100)
# 14                         (The Jaws Collection, 3)               (War, 77)
# 15             (Diary of a Wimpy Kid Collection, 3)             (Music, 68)
# 16                             (Cars Collection, 3)           (Western, 29)
# 17                       (Alex Cross Collection, 3)       (Documentary, 17)
# 18                              (Mexico Trilogy, 3)            (Foreign, 7)
# 19                     (Three Heroes Collection, 3)            (NO DATA, 4)
# 20                    (Indiana Jones Collection, 3)           (TV Movie, 1)
# 21                  (The Dark Knight Collection, 3)                    None
# 22                        (Halloween Collection, 3)                    None
# 23      (Planet of the Apes Original Collection, 3)                    None
# 24                    (The Wolverine Collection, 3)                    None
# 25   (Star Trek: The Original Series Collection, 3)                    None
# 26                      (Scary Movie Collection, 3)                    None
# 27         (Pirates of the Caribbean Collection, 3)                    None
# 28             (The Princess Diaries Collection, 2)                    None
# 29                  (The Transporter Collection, 2)                    None
# 30                           (Batman Collection, 2)                    None
# 31            (The Lord of the Rings Collection, 2)                    None
# 32                            (X-Men Collection, 2)                    None
# 33                        (Peter Pan Collection, 2)                    None
# 34                          (Mad Max Collection, 2)                    None
# 35                  (The Blue Lagoon collection, 2)                    None
# 36                       (Hellraiser Collection, 2)                    None
# 37              (Would I Lie to You? Collection, 2)                    None
# 38                           (Clerks Collection, 2)                    None
# 39                    (The Jack Ryan Collection, 2)                    None
# 40  (I Know What You Did Last Summer Collection, 2)                    None
# 41                   (Daddy Day Camp Collection, 2)                    None
# 42         (My Big Fat Greek Wedding Collection, 2)                    None
# 43                     (The Hangover Collection, 2)                    None
# 44                         (Predator Collection, 2)                    None
# 45                        (Before... Collection, 2)                    None
# 46                          (Step Up Collection, 2)                    None
# 47                       (The Hobbit Collection, 2)                    None
# 48                         (Kick-Ass Collection, 2)                    None
# 49                         (Mall Cop Collection, 2)                    None
#
#                              production_companies  \
# 0                             (Warner Bros., 170)
# 1                       (Universal Pictures, 154)
# 2                       (Paramount Pictures, 132)
# 3   (Twentieth Century Fox Film Corporation, 121)
# 4                         (Columbia Pictures, 83)
# 5                           (New Line Cinema, 68)
# 6                 (Metro-Goldwyn-Mayer (MGM), 63)
# 7                                   (NO DATA, 57)
# 8                      (Walt Disney Pictures, 55)
# 9                       (Touchstone Pictures, 50)
# 10            (Columbia Pictures Corporation, 47)
# 11                         (Relativity Media, 47)
# 12                         (TriStar Pictures, 40)
# 13                           (United Artists, 37)
# 14                (Village Roadshow Pictures, 35)
# 15                            (Miramax Films, 34)
# 16                                   (Canal+, 32)
# 17                       (Dune Entertainment, 28)
# 18                           (DreamWorks SKG, 27)
# 19                      (Regency Enterprises, 27)
# 20                                (Lionsgate, 25)
# 21                     (Summit Entertainment, 23)
# 22                      (Working Title Films, 23)
# 23                 (Fox Searchlight Pictures, 22)
# 24                        (Fox 2000 Pictures, 22)
# 25                            (Original Film, 21)
# 26                  (Epsilon Motion Pictures, 20)
# 27                       (Legendary Pictures, 19)
# 28                 (Morgan Creek Productions, 19)
# 29                (Castle Rock Entertainment, 18)
# 30                     (Amblin Entertainment, 18)
# 31                                (BBC Films, 18)
# 32                              (StudioCanal, 18)
# 33                          (Dimension Films, 18)
# 34                       (Hollywood Pictures, 18)
# 35                    (Blumhouse Productions, 17)
# 36                           (Orion Pictures, 16)
# 37                              (Screen Gems, 16)
# 38                     (New Regency Pictures, 16)
# 39                         (Millennium Films, 16)
# 40                   (Spyglass Entertainment, 16)
# 41                           (Focus Features, 16)
# 42                    (Imagine Entertainment, 15)
# 43                          (Silver Pictures, 15)
# 44                        (Participant Media, 15)
# 45                        (TSG Entertainment, 15)
# 46                          (Eon Productions, 14)
# 47                   (Dune Entertainment III, 13)
# 48                  (Lakeshore Entertainment, 12)
# 49                        (Studio Babelsberg, 12)
#
#                 production_countries       spoken_languages  \
# 0   (United States of America, 1724)        (English, 1905)
# 1              (United Kingdom, 255)        (Français, 190)
# 2                      (France, 139)         (Español, 180)
# 3                     (Germany, 127)         (Deutsch, 115)
# 4                       (Canada, 89)         (Pусский, 113)
# 5                        (India, 68)         (Italiano, 91)
# 6                    (Australia, 46)              (日本語, 60)
# 7                        (Italy, 41)              (普通话, 52)
# 8                       (Russia, 34)           (हिन्दी, 48)
# 9                        (Japan, 32)                 (, 34)
# 10                       (China, 32)        (Português, 32)
# 11                       (Spain, 28)          (العربية, 32)
# 12                   (Hong Kong, 24)          (한국어/조선말, 26)
# 13                     (Belgium, 15)            (Latin, 23)
# 14                     (NO DATA, 14)            (தமிழ், 21)
# 15                 (New Zealand, 14)        (广州话 / 廣州話, 20)
# 16                     (Ireland, 13)          (ภาษาไทย, 20)
# 17              (Czech Republic, 13)           (Polski, 16)
# 18                      (Mexico, 11)            (Český, 15)
# 19                 (South Korea, 10)           (Magyar, 14)
# 20                 (Netherlands, 10)         (ελληνικά, 12)
# 21                       (Sweden, 8)          (svenska, 11)
# 22                 (South Africa, 7)         (עִבְרִית, 11)
# 23         (United Arab Emirates, 7)        (Tiếng Việt, 9)
# 24                   (Luxembourg, 6)            (Türkçe, 8)
# 25                      (Hungary, 6)            (తెలుగు, 7)
# 26                      (Finland, 6)             (Dansk, 7)
# 27                  (Switzerland, 5)         (Kiswahili, 7)
# 28                       (Brazil, 5)              (اردو, 7)
# 29                      (Denmark, 5)             (فارسی, 5)
# 30                      (Romania, 5)             (suomi, 5)
# 31                      (Austria, 4)       (Український, 5)
# 32                       (Greece, 4)        (Nederlands, 4)
# 33                       (Norway, 4)             (Norsk, 4)
# 34                      (Morocco, 3)            (Română, 4)
# 35                    (Argentina, 3)         (Afrikaans, 3)
# 36                     (Bulgaria, 3)            (ਪੰਜਾਬੀ, 3)
# 37                       (Poland, 3)           (NO DATA, 3)
# 38                      (Iceland, 2)       (No Language, 3)
# 39                       (Taiwan, 2)            (Srpski, 3)
# 40                        (Malta, 2)          (Íslenska, 3)
# 41                     (Pakistan, 2)             (বাংলা, 2)
# 42                       (Israel, 2)    (български език, 2)
# 43                      (Tunisia, 2)             (shqip, 2)
# 44                      (Ukraine, 2)  (Bahasa indonesia, 2)
# 45                       (Turkey, 2)         (Esperanto, 2)
# 46                        (Chile, 2)           (euskera, 2)
# 47                    (Singapore, 2)            (Somali, 2)
# 48                      (Bahamas, 2)            (Català, 2)
# 49                       (Serbia, 1)          (Hrvatski, 2)
#
#                          Keywords                         cast  \
# 0                  (NO DATA, 123)      (Samuel L. Jackson, 25)
# 1     (duringcreditsstinger, 115)         (Robert De Niro, 24)
# 2            (woman director, 99)         (Morgan Freeman, 23)
# 3                    (murder, 96)           (Bruce Willis, 23)
# 4            (based on novel, 91)           (Bruce McGill, 23)
# 5          (independent film, 86)           (J.K. Simmons, 22)
# 6                  (violence, 70)          (Jason Statham, 20)
# 7                  (dystopia, 70)         (George Clooney, 20)
# 8       (aftercreditsstinger, 69)        (Forest Whitaker, 20)
# 9                     (sport, 62)       (Sigourney Weaver, 20)
# 10                  (revenge, 58)            (Owen Wilson, 20)
# 11                (biography, 56)           (Nicolas Cage, 20)
# 12                   (sequel, 55)            (Liam Neeson, 20)
# 13               (friendship, 50)     (Sylvester Stallone, 19)
# 14                 (suspense, 48)          (Michael Caine, 19)
# 15                      (sex, 48)          (John Turturro, 19)
# 16                   (police, 47)            (Keith David, 18)
# 17                 (teenager, 44)           (Frank Welker, 18)
# 18              (los angeles, 43)         (John Leguizamo, 18)
# 19                   (prison, 41)          (Robert Duvall, 18)
# 20                     (love, 41)           (Willem Dafoe, 18)
# 21                   (nudity, 38)              (Ed Harris, 18)
# 22            (female nudity, 37)          (Mark Wahlberg, 18)
# 23                 (new york, 37)         (Susan Sarandon, 18)
# 24                       (3d, 37)              (Brian Cox, 17)
# 25                     (drug, 36)            (Bill Murray, 17)
# 26  (father son relationship, 36)    (Christopher Plummer, 17)
# 27                  (musical, 35)          (Jim Broadbent, 17)
# 28              (high school, 34)             (Matt Damon, 17)
# 29           (based on comic, 33)         (Bradley Cooper, 17)
# 30                  (wedding, 32)      (Denzel Washington, 17)
# 31               (corruption, 31)           (John Goodman, 17)
# 32                    (alien, 31)  (Arnold Schwarzenegger, 16)
# 33           (london england, 30)          (Harrison Ford, 16)
# 34                   (future, 29)             (Mel Gibson, 16)
# 35               (kidnapping, 29)         (Cate Blanchett, 16)
# 36                (superhero, 29)           (Gene Hackman, 16)
# 37                    (magic, 29)          (Julia Roberts, 16)
# 38            (investigation, 29)              (Tom Hanks, 16)
# 39                   (remake, 28)       (Catherine Keener, 16)
# 40                   (family, 28)         (John C. Reilly, 16)
# 41                (detective, 28)         (Christian Bale, 16)
# 42                   (escape, 27)           (Alec Baldwin, 16)
# 43                  (suicide, 27)         (Allison Janney, 15)
# 44            (serial killer, 26)         (Dwayne Johnson, 15)
# 45                    (paris, 26)             (Tom Cruise, 15)
# 46          (dying and death, 25)          (Colin Farrell, 15)
# 47                    (death, 25)         (Peter Stormare, 15)
# 48      (based on true story, 25)        (Brendan Gleeson, 15)
# 49                (explosion, 25)     (Christopher Walken, 15)
#
#                           crew
# 0       (Robert Rodriguez, 44)
# 1            (Avy Kaufman, 37)
# 2    (James Newton Howard, 36)
# 3       (Francine Maisler, 35)
# 4         (Deborah Aquila, 35)
# 5       (Steven Spielberg, 33)
# 6        (Jerry Goldsmith, 33)
# 7           (Mary Vernieu, 32)
# 8             (Luc Besson, 31)
# 9            (Tricia Wood, 28)
# 10           (John Debney, 27)
# 11           (Hans Bjerno, 26)
# 12            (Sarah Finn, 26)
# 13        (Neal H. Moritz, 26)
# 14          (James Horner, 26)
# 15      (Janet Hirshenson, 26)
# 16           (Hans Zimmer, 26)
# 17           (Mindy Marin, 26)
# 18        (John Papsidera, 25)
# 19         (Bob Weinstein, 25)
# 20      (Harvey Weinstein, 25)
# 21         (Dan O'Connell, 25)
# 22          (Bruce Berman, 25)
# 23          (Jane Jenkins, 24)
# 24  (Francis Ford Coppola, 24)
# 25     (Steven Soderbergh, 23)
# 26         (Peter Jackson, 23)
# 27         (Amanda Mackey, 23)
# 28         (Arnon Milchan, 23)
# 29          (George Lucas, 23)
# 30           (John Powell, 22)
# 31        (Denise Chamian, 22)
# 32        (Marco Beltrami, 22)
# 33           (Joel Silver, 22)
# 34            (Mark Isham, 22)
# 35          (Danny Elfman, 22)
# 36           (Scott Rudin, 21)
# 37          (Randi Hiller, 21)
# 38         (Graeme Revell, 21)
# 39        (Cathy Sandrich, 21)
# 40        (Alan Silvestri, 21)
# 41        (Clint Eastwood, 21)
# 42    (Paul W.S. Anderson, 21)
# 43         (John T. Cucci, 21)
# 44       (Christophe Beck, 20)
# 45            (Wes Craven, 20)
# 46           (Dean Semler, 20)
# 47   (Christopher Assells, 20)
# 48          (Ivan Reitman, 20)
# 49     (Richard Linklater, 20)

# %%
# formatted_df = train_df.copy()
# formatted_df["budget"] = formatted_df["budget"].apply("${:,.2f}".format)
# formatted_df["revenue"] = formatted_df["revenue"].apply("${:,.2f}".format)

# formatted_df.sort_values("roi", ascending=False)

# %%
pd.set_option("display.float_format", lambda x: "{:,.2f}".format(x))

fig, ax = plt.subplots(figsize=(24,8))

train_df[["release_year", "budget", "revenue"]].groupby("release_year").sum().plot(ax=ax)

ax.set_title("Total Budget & Revenue per Year", fontsize="xx-large")

ax.legend(fontsize="x-large")

plt.tight_layout()

# %%
pd.reset_option("display.float_format")

# %%
fig, ax = plt.subplots(figsize=(24,8), sharex=True, sharey=True)

# train_df[["release_month", "budget", "revenue"]].groupby("release_month").sum().plot(ax=ax)

data = train_df[["release_month", "budget", "revenue"]].groupby("release_month").sum()

sns.set_color_codes("pastel")
sns.barplot(x=list(range(12)), y="revenue", data=data, ax=ax, label="Total Revenue", color="b")

sns.set_color_codes("muted")
sns.barplot(x=list(range(12)), y="budget", data=data, ax=ax,
            label="Total Budget", color="b")

ax.set_xticks(range(12))
ax.set_xticklabels(calendar.month_name[1:], fontsize="large")

# ax.set_yticks(range(30))
# ax.set_yticklabels(range(1,31))

ax.set_title("Total Budget & Revenue per Month", fontsize="xx-large")

ax.legend(ncol=2, frameon=True, fontsize="x-large")
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %%
def find_in_movie(row, name):
    """
    input:
        row is a list of dictionaries
        name is a string
    
    output:
        boolean value
    """
    for ele in row:
        if ele["name"].lower() == name.lower():
            return True
    return False

def movie_search(df, name, category):
    """
    input:
        df is a pandas dataframe.
        name is the string to query in the chosen category.
        category is a string of the column name to query.
        categories options include:
            belongs_to_collection
            genres
            production_companies
            production_countries
            spoken_languages
            Keywords
            cast
            crew
    
    output:
        pandas dataframe with filtered search results
    """
    return df[df[category].apply(lambda row: find_in_movie(row, name))]

# %%
# movie_search(train_df, "nicolas cage", "cast")[["revenue"]].sum()

# for actor, count in top_counts_df["cast"][:50]:
#     rev = float(movie_search(train_df, actor, "cast")[["revenue"]].sum())
#     bud = float(movie_search(train_df, actor, "cast")[["budget"]].sum())
#     net = rev - bud

# %%
def box_office_from_search(category, top=21, data_to_find=top_counts_df, df=train_df):
    """
    input:
        category is a string of the column name to query.
        categories options include:
            belongs_to_collection
            genres
            production_companies
            production_countries
            spoken_languages
            Keywords
            cast
            crew
        top is an int of how many elements to iterate over in chosen category.
        data_to_find is the where the search terms come from.
        df is the dataframe being searched.
        
    output:
        names is a list of strings used to search the df.
        budgets is a list of floats.
        revenues is a list of floats.
        nets is a list of revenues minus budgets.
    """
    names = [name for name, count in data_to_find[category][:top]]
    budgets = []
    revenues = []
    nets = []
    
    for ele, count in data_to_find[category][:top]:
        budget = float(movie_search(df, ele, category)[["budget"]].sum())
        revenue = float(movie_search(df, ele, category)[["revenue"]].sum())
        net = revenue - budget
        
        budgets.append(budget)
        revenues.append(revenue)
        nets.append(net)
    
    return names, budgets, revenues, nets

# %%
fig, ax = plt.subplots(figsize=(13, 13))

actor_names, top_50_actor_budgets, top_50_actor_revenues, top_50_actor_nets = box_office_from_search("cast", top=50)

sns.barplot(x=top_50_actor_nets, y=list(range(50)), orient="h", ax=ax)

ax.set_yticklabels(actor_names)
    
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(13, 13))

genre_names, genre_budgets, genre_revenues, genre_nets = box_office_from_search("genres")

sns.barplot(x=genre_nets, y=list(range(len(genre_nets))), orient="h", ax=ax)

ax.set_yticklabels(genre_names)
    
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(13, 13))

crew_names, crew_budgets, crew_revenues, crew_nets = box_office_from_search("crew", top=50)

sns.barplot(x=crew_nets, y=list(range(len(crew_nets))), orient="h", ax=ax)

ax.set_yticklabels(crew_names)
    
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(13, 13))

production_company_names, production_company_budgets, production_company_revenues, production_company_nets = box_office_from_search("production_companies", top=50)

sns.barplot(x=production_company_budgets, y=list(range(len(production_company_budgets))), orient="h", ax=ax)

ax.set_yticklabels(production_company_names)

plt.tight_layout()

# %%
indie_df = movie_search(train_df, "independent film", "Keywords")

fig, ax = plt.subplots(figsize=(13, 13))

indie_company_names, indie_company_budgets, indie_company_revenues, indie_company_nets = box_office_from_search("production_companies", top=len(indie_df), df=indie_df)

sns.barplot(x=indie_company_nets, y=list(range(len(indie_company_nets))), orient="h", ax=ax)

ax.set_yticklabels(indie_company_names)

plt.tight_layout()
